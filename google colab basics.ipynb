# %% [markdown]
# system Specifications

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# ...

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13302928 kB
# MemFree:        10551780 kB
# MemAvailable:   12498136 kB
# Buffers:          124488 kB
# Cached:          1949272 kB
# SwapCached:            0 kB
# Active:          1020124 kB
# Inactive:        1494760 kB
# Active(anon):     397904 kB
# Inactive(anon):      420 kB
# Active(file):     622220 kB
# Inactive(file):  1494340 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               420 kB
# Writeback:             0 kB
# AnonPages:        441228 kB
# Mapped:           239212 kB
# Shmem:              1144 kB
# KReclaimable:     142544 kB
# Slab:             186792 kB
# SReclaimable:     142544 kB
# SUnreclaim:        44248 kB
# KernelStack:        4704 kB
# PageTables:         5916 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6651464 kB
# Committed_AS:    3104676 kB
# VmallocTotal:   34359738367 kB
# ...

# %% [markdown]
# Installing Libraires

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
print("Machine learning")
# Out:
# Machine learning
