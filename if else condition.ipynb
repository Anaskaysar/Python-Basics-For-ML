# %% [markdown]
# If else statement

# %%
a=30
b=50
if(a>b):
    print('a is greater than b')

else:
    print('b is grater than a')
# Out:
# b is grater than a

# %% [markdown]
# if else bia taking input

# %%
a=int(input('Enter the number 1 : '))
b=int(input('Enter the number 2 : '))
if(a>b):
    print('a is greater than b')

else:
    print('b is grater than a')
# Out:
# Enter the number 1 : 10
# Enter the number 2 : 22
# b is grater than a

# %% [markdown]
# else if

# %%
a=15
b=25
c=30
if(b<a>c):
    print('a is greatest')

elif(a<b>c):
    print('b is gratest')
else :
  print('C is greater')
# Out:
# C is greater

# %% [markdown]
# nested if

# %%
a=20
b=10
c=29
if(a>b):
  if(a>c):
    print("a is the greatest")
  else:
    print("c is the gratest")
else:
  if(b>c):
    print("b is gratest")
  else:
    print("C is greatest")
# Out:
# c is the gratest
