# %% [markdown]
# For loop

# %%
for i in range(5): #comment
  laptopPrice=int(input("Enter The Number : "))
# Out:
# Enter The Number : 12
# Enter The Number : 23
# Enter The Number : 22
# Enter The Number : 22
# Enter The Number : 1

# %% [markdown]
# list

# %%
numbers=[10,5,11,12,1]
sum=0
for i in numbers:
  print(i)
  sum=sum+i
print(sum)
# Out:
# 10
# 5
# 11
# 12
# 1
# 39
