# %% [markdown]
# Functions:
#
# Function is a block of code that can be reused in a Program

# %% [markdown]
# Factorial of a Number

# %% [markdown]
# Factorial of a number is the product of all the positive integers less than or equal to the given number

# %% [markdown]
# Factorial of 5 = 5 x 4 x 3 x 2 x 1 = 120

# %%
number = int(input(' Enter a number to find its factorial : '))

factorial = 1

if number == 0:
  print(' The Factorial of 0 is 1')

else:
  for i in range(1, number+1):    #range(1 to 6 including 1 excluding 6)
    factorial = factorial*i
  print('The factorial of ',number,' is',factorial)
# Out:
#  Enter a number to find its factorial : 2
# The factorial of  2  is 2

# %% [markdown]
# Factoraial Function

# %%
def factorial_value(num):

  factorial = 1

  if num == 0:
    return factorial

  else:
    for i in range(1, num+1):
      factorial = factorial*i
    return factorial

# %%
print(factorial_value(5))
# Out:
# 120

# %%
print(factorial_value(10))
# Out:
# 3628800

# %%
print(factorial_value(6))
# Out:
# 720
